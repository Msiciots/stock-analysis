# %%
from __future__ import (absolute_import, division, print_function,
                        unicode_literals)
# %matplotlib inline
from datetime import datetime
# Import the backtrader platform
import backtrader as bt

# Import the self-defined strategy
from strategy.ma_rsi import ma_rsi 
                
if __name__ == '__main__':
    # Create a cerebro entity
    cerebro = bt.Cerebro()

    # Add a strategy
    cerebro.addstrategy(ma_rsi,ma_period=15)
    
    # Add the Data Feed to Cerebro
    data = bt.feeds.YahooFinanceData(dataname='2330.TW', fromdate=datetime(2020, 1, 1),todate=datetime(2020, 12, 31))
    cerebro.adddata(data)

    # Set our desired cash start
    cerebro.broker.setcash(1000.0)

    # Add a FixedSize sizer according to the stake
#     cerebro.addsizer(bt.sizers.FixedSize, stake=10)

    # Set the commission
    cerebro.broker.setcommission(commission=0.0)

    # Print out the starting conditions
    print('Starting Portfolio Value: %.2f' % cerebro.broker.getvalue())

    # Run over everything
    cerebro.run()

    # Print out the final result
    print('Final Portfolio Value: %.2f' % cerebro.broker.getvalue())

    # Plot the result
    cerebro.plot()
# Out:
# Starting Portfolio Value: 1000.00
# 2020-05-07, BUY CREATE, 290.90
# 2020-05-08, BUY EXECUTED, Price: 293.35, Cost: 293.35, Comm 0.00
# 2020-05-08, SELL CREATE, 290.90
# 2020-05-11, SELL EXECUTED, Price: 293.35, Cost: 293.35, Comm 0.00
# 2020-05-11, OPERATION PROFIT, GROSS 0.00, NET 0.00
# 2020-05-11, BUY CREATE, 294.33
# 2020-05-12, BUY EXECUTED, Price: 290.90, Cost: 290.90, Comm 0.00
# 2020-05-12, SELL CREATE, 288.46
# 2020-05-13, SELL EXECUTED, Price: 286.50, Cost: 290.90, Comm 0.00
# 2020-05-13, OPERATION PROFIT, GROSS -4.40, NET -4.40
# 2020-05-15, BUY CREATE, 291.39
# 2020-05-18, BUY EXECUTED, Price: 284.55, Cost: 284.55, Comm 0.00
# 2020-05-18, SELL CREATE, 283.57
# 2020-05-19, SELL EXECUTED, Price: 287.48, Cost: 284.55, Comm 0.00
# 2020-05-19, OPERATION PROFIT, GROSS 2.93, NET 2.93
# 2020-05-21, BUY CREATE, 290.90
# 2020-05-22, BUY EXECUTED, Price: 287.97, Cost: 287.97, Comm 0.00
# 2020-05-22, SELL CREATE, 285.53
# 2020-05-25, SELL EXECUTED, Price: 284.06, Cost: 287.97, Comm 0.00
# 2020-05-25, OPERATION PROFIT, GROSS -3.91, NET -3.91
# 2020-05-26, BUY CREATE, 288.95
# 2020-05-27, BUY EXECUTED, Price: 290.41, Cost: 290.41, Comm 0.00
# 2020-05-28, SELL CREATE, 287.48
# 2020-05-29, SELL EXECUTED, Price: 285.53, Cost: 290.41, Comm 0.00
# 2020-05-29, OPERATION PROFIT, GROSS -4.88, NET -4.88
# 2020-06-01, BUY CREATE, 288.95
# 2020-06-02, BUY EXECUTED, Price: 289.44, Cost: 289.44, Comm 0.00
# 2020-06-29, SELL CREATE, 307.52
# 2020-06-30, SELL EXECUTED, Price: 309.00, Cost: 289.44, Comm 0.00
# 2020-06-30, OPERATION PROFIT, GROSS 19.56, NET 19.56
# 2020-07-01, BUY CREATE, 312.94
# 2020-07-02, BUY EXECUTED, Price: 314.42, Cost: 314.42, Comm 0.00
# 2020-08-12, SELL CREATE, 412.99
# 2020-08-13, SELL EXECUTED, Price: 421.86, Cost: 314.42, Comm 0.00
# 2020-08-13, OPERATION PROFIT, GROSS 107.44, NET 107.44
# 2020-08-13, BUY CREATE, 422.84
# 2020-08-14, BUY EXECUTED, Price: 417.92, Cost: 417.92, Comm 0.00
# 2020-08-14, SELL CREATE, 420.87
# 2020-08-17, SELL EXECUTED, Price: 420.87, Cost: 417.92, Comm 0.00
# 2020-08-17, OPERATION PROFIT, GROSS 2.95, NET 2.95
# 2020-08-17, BUY CREATE, 428.76
# 2020-08-18, BUY EXECUTED, Price: 433.69, Cost: 433.69, Comm 0.00
# 2020-08-19, SELL CREATE, 421.36
# 2020-08-20, SELL EXECUTED, Price: 420.87, Cost: 433.69, Comm 0.00
# 2020-08-20, OPERATION PROFIT, GROSS -12.82, NET -12.82
# 2020-08-25, BUY CREATE, 428.26
# 2020-08-26, BUY EXECUTED, Price: 429.25, Cost: 429.25, Comm 0.00
# 2020-08-31, SELL CREATE, 420.38
# 2020-09-01, SELL EXECUTED, Price: 423.83, Cost: 429.25, Comm 0.00
# 2020-09-01, OPERATION PROFIT, GROSS -5.42, NET -5.42
# 2020-09-01, BUY CREATE, 428.76
# 2020-09-02, BUY EXECUTED, Price: 434.67, Cost: 434.67, Comm 0.00
# 2020-09-04, SELL CREATE, 422.84
# 2020-09-07, SELL EXECUTED, Price: 421.86, Cost: 434.67, Comm 0.00
# 2020-09-07, OPERATION PROFIT, GROSS -12.81, NET -12.81
# 2020-09-10, BUY CREATE, 428.76
# 2020-09-11, BUY EXECUTED, Price: 429.25, Cost: 429.25, Comm 0.00
# 2020-09-23, SELL CREATE, 429.62
# 2020-09-24, SELL EXECUTED, Price: 421.70, Cost: 429.25, Comm 0.00
# 2020-09-24, OPERATION PROFIT, GROSS -7.55, NET -7.55
# 2020-10-06, BUY CREATE, 435.57
# 2020-10-07, BUY EXECUTED, Price: 431.11, Cost: 431.11, Comm 0.00
# 2020-10-26, SELL CREATE, 445.98
# 2020-10-27, SELL EXECUTED, Price: 443.50, Cost: 431.11, Comm 0.00
# 2020-10-27, OPERATION PROFIT, GROSS 12.39, NET 12.39
# 2020-11-04, BUY CREATE, 445.98
# 2020-11-05, BUY EXECUTED, Price: 447.46, Cost: 447.46, Comm 0.00
# 2020-12-23, SELL CREATE, 506.92
# 2020-12-24, SELL EXECUTED, Price: 508.92, Cost: 447.46, Comm 0.00
# 2020-12-24, OPERATION PROFIT, GROSS 61.46, NET 61.46
# 2020-12-25, BUY CREATE, 508.92
# 2020-12-28, BUY EXECUTED, Price: 509.91, Cost: 509.91, Comm 0.00
# Final Portfolio Value: 1167.89
# <img src="data:image/png;base64,..." width="431.8518823589666">
